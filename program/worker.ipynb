# %%
import os

from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________
#
# Изменение расширения файлов

# %%
for file in os.listdir("data"):
    if file.endswith(".xlsx"):

        file = Path(file).stem

        df = pd.read_excel(f'data/{file}.xlsx', dtype=str)
        df.to_csv(f"data/{file}.csv", index=False, sep=',')

        os.remove(f'data/{file}.xlsx')

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________
#
# Графики

# %%
dfd = pd.read_csv('data/train.csv')
dft = pd.read_csv('data/test.csv')

###############################################################################################

dfd.info()

###############################################################################################

x = dfd['dt']
y = dfd['Цена на арматуру']

plt.plot(x, y)
plt.show()

###############################################################################################

x = dft['dt']
y = dft['Цена на арматуру']

plt.plot(x, y)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   dt                400 non-null    object
#  1   Цена на арматуру  400 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 6.4+ KB
